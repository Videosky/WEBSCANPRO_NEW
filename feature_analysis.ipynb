# %%
import pandas as pd

df = pd.read_csv("features_extracted.csv")

# SQL keyword stats
print("Inputs with SQL keywords:", df["contains_sql_keyword"].sum())

# HTML tag stats
print("Inputs with HTML tags:", df["contains_html_tag"].sum())

# Param type distribution
print(df["param_type"].value_counts())
# Out:
# Inputs with SQL keywords: 0
# Inputs with HTML tags: 0
# param_type
# text        1
# password    1
# submit      1
# hidden      1
# Name: count, dtype: int64
